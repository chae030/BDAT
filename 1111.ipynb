# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 28.6 MB/s  0:00:00eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pandas]2m2/3 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [requests]2/5 [charset_normalizer]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.plot([1,2,3,4])
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()
# Out:
# /opt/anaconda3/envs/BDAT/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 52629 (\N{HANGUL SYLLABLE CUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.plot([1,2,3,4], [3,4,5,6])
plt.plot([1,2,3,4], [1,2,3,4])
plt.xlabel('X축')
plt.ylabel('Y축')
plt.show()

# %%
plt.plot([3,4,5,6],[1,2,3,4], 'gv')
plt.show()

# %%
font_path = "/Users/parkchaeyeon/Library/Fonts/윤고딕350.ttf"

from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname=font_path).get_name()

rc('font', family=font_name)

# %%
import pandas as pd 
import requests

# %%
url = "https://openapi.tour.go.kr/openapi/service"
key = "2%2BpyRPne6PrYbjIkdEmXQclTG75zQ9x%2BIVqRzw81dVPLXKSboeWj495Kg%2B5qyeGMC5b1iLWLsdQ%2BshAiwhCcdg%3D%3D"
params = {
    
}
